# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import quandl

# %% [markdown]
# ### Make a Basic Data Call
# Uses https://www.quandl.com/search

# %%
quandl.ApiConfig.api_key = "8aXL5FDq4eo5REVdCpoF"

# %%
start_date='2000-01-01'
end_date='2017-01-01'

mydata = quandl.get(["WIKI/FB.4", "WIKI/EBAY.4", "WIKI/MSFT.4"],start_date=start_date,end_date=end_date)

# %%
mydata.head()
# Out:
#             WIKI/FB - Close  WIKI/EBAY - Close  WIKI/MSFT - Close
# Date
# 2000-01-03              NaN              141.3             116.56
# 2000-01-04              NaN              127.3             112.62
# 2000-01-05              NaN              135.0             113.81
# 2000-01-06              NaN              134.9             110.00
# 2000-01-07              NaN              134.8             111.44

# %%
mydata.rolling(7).mean().plot(figsize=(16,6))
